# %%
# 튜플은 어떻게 만들까?

t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3 #괄호 생략 가능
t5 = ("a", "b", ("ab", "cd"))
t6 = tuple()

print(type(t3))
# Out:
# <class 'tuple'>

# %%
t1 = (10, )
t2 = 10,

print(type(t1))
print(type(t2))

d1 = (10) # d1 = 10

print(type(d1))

num = 10, 20
print(type(num))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
## 튜플의 요소값을 지우거나 변경하려고 하면?
t1 = (1, 2, "a", "b")
## del t1[2] 튜플은 지우는것은 오류
## t1[2] = "c" 튜플은 수정하는 것도 오류

# %%
## 튜플 인덱싱
t1 = (1, 2, "a", "b")
print(t1[0])
print(t1[-1])
# Out:
# 1
# b

# %%
## 튜플 슬라이싱
t1 = (1, 2, "a", "b")
t1[1:]
# Out:
# (2, 'a', 'b')

# %%
## 튜플 더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)
print(t1 + t2)
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
## 튜플 곱하기
t2 = (3, 4)
print(t2 * 3)
print(t2)
# Out:
# (3, 4, 3, 4, 3, 4)
# (3, 4)

# %%
t1 = (1, 2, "a", "b")
print(len(t1))
# Out:
# 4
