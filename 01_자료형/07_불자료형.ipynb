# %%
a = True
b = False

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(1 == 1)
print(1 > 2)
print(1 < 2)
# Out:
# True
# False
# True

# %%
print(bool(1 == 1))
print(bool("python"))
print(bool(""))
print(bool(10))
print(bool(0))
print(bool([1, 2, 3]))
print(bool([]))
# Out:
# True
# True
# False
# True
# False
# True
# False

# %%
## 논라연산자
#and
#or

print(True and True)
print(True and False)
print(False and True)
print(False and False)
print("="*10)
print(True or True)
print(True or False)
print(False or True)
print(False or False)

## 비교연산자
#>(크다, 초과)
#<(작다, 미만)
#>=(크거나 같다, 이상)
#<=(작거나 같다, 이하)
#!=(다르다) #<>
#==(같다)
# Out:
# True
# False
# False
# False
# ...
# True
# True
# True
# False
