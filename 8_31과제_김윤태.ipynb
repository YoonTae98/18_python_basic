# %%
# 1. https://himzei.com 회원기입하고 자기소개를 작성해해주세요(각오, MBTI, 파이썬으로 구현하고 싶은 것 등)
## 각오 6개월동안 잘해보겠습니다 잘부탁드립니다
## MBTI INFP
## 파이썬으로 구혀하고 싶은 것 : 실시간 변동 데이터를 크롤링하여 스트리밍 데이터 분석

# %%
# 2. 파이썬은 어떤 종류의 프로그래밍 언어인가? 다음 빈칸을 채우시오.
## 파이썬은 (스크립트) 언어로, 코드를 한 줄씩 읽어서 바로 실행하는 (인터프라터)가 필요하다.

# %%
# 3. 파이썬 공식 다운로드 사이트 주소를 쓰시오, 설치 시 패스옵션을 체크해야 하는 이유와 안 했을 경우 어떻게 해야 하는지 서술하시오.
## python.org
## 명령 프롬프트나 터미널에서 파이썬의 설치 위치를 별도로 지정하지 않고 python 명령어만으로 실행하기 위해서이다.
## PATH 옵션을 체크하지 않았다면 환경 변수 PATH에 파이썬이 설치된 경로를 직접 추가하거나, 파이썬을 재설치하면서 PATH 옵션을 체크해야 한다.

# %%
# 4. 파이썬 설치 후, 설치가 제대로 되었는지 확인하는 명령어를 쓰시오.
## 명령 프롬프트(터미널)에서: python --version

# %%
'''
5. 다음 중 파이썬의 특징으로 옳은 것을 모두 고르시오.
① 무료이며 오픈소스이다
② 컴파일 언어이다
③ 다양한 운영체제에서 실행 가능하다
④ 문법이 복잡하여 배우기 어렵다
⑤ 풍부한 라이브러리를 제공한다`
'''

## 1, 3, 5 (2.인터프라터언어 4.비교적 간단 배우기 쉬움)
# Out:
# '\n5. 다음 중 파이썬의 특징으로 옳은 것을 모두 고르시오.\n① 무료이며 오픈소스이다\n② 컴파일 언어이다\n③ 다양한 운영체제에서 실행 가능하다\n④ 문법이 복잡하여 배우기 어렵다\n⑤ 풍부한 라이브러리를 제공한다`\n'

# %%
# 6. 명령 프롬프트(터미널)에서 파이썬 대화형 모드로 진입하는 명령어를 쓰시오.
## python

# %%
# 7. 대화형 모드에서 빠져나오는 방법 2가지를 쓰시오.
## exit(), quit()

# %%
# 8. 대화형 모드에서 `>>>` 기호는 무엇을 의미하는가?
## python 인터프리터가 사용자의 코드 입력을 기다리고 있음

# %%
# 9. 파이썬 파일의 확장자는 무엇이며, 이 파일을 실행하는 명령어를 쓰시오.
## 확장자: .py
## 실행 명령어: python 파일명.py

# %%
# 10. 현재 폴더에 `hello.py` 파일이 있을 때, 이를 실행하는 명령어를 쓰시오.
## python .\hello.py

# %%
# 11. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
# - 현재 위치: C:\Users\student
# - 파일 위치: C:\Users\student\projects\mycode.py

## dir
## cd projects
## python mycode.py

# %%
# 12. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
# - 현재 위치: C:\Users\student\documents
# - 파일 위치: C:\Users\student\projects\test.py

## cd ..
## cd projects
## python test.py

# %%
# 13. 절대 경로(Absolute Path)와 상대 경로(Relative Path)의 차이를 설명하시오.
## 절대 경로는 파일이나 폴더의 전체위치면 상대 경로는 현재 위치를 기준으로 나타낸다.
## ex) 절대 경로: C:\Users\student\projects\mycode.py ,상대 경로: projects\mycode.py

# %%
'''
14. 다음 중 절대 경로에 해당하는 것을 모두 고르시오.
① hello.py
② ./scripts/main.py
③ C:\Users\student\code\app.py
④ ../data/file.txt
⑤ /home/user/projects/test.py
'''

# 3, 5

# %%
# 15. 상대 경로에서 사용하는 다음 기호의 의미를 쓰시오.
## (1) .  (점 하나)   : 현재 폴더
## (2) .. (점 두 개)  : 상위 폴더
## (3) /  또는  \    : 경로 구분자

# %%
# 16. 명령 프롬프트에서 현재 디렉토리를 확인하는 명령어를 쓰시오.
## cd

# %%
# 17. 명령 프롬프트에서 디렉토리를 이동하는 명령어를 쓰시오. 예: projects 폴더로 이동
## python
## dir
## cd projects

# %%
# 18.  IDE란 무엇의 약자이며, 한글로 무엇이라고 하는지 쓰시오. 또한 IDE의 역할을 간단히 설명하시오.
## IDE는 Integrated Development Environment의 약자로, 한글로 통합 개발 환경이라고 한다. 프로그램 작성, 실행, 디버깅 등 개발에 필요한 기능을 하나의 환경에서 사용할 수 있도록 한다.

# %%
'''
19. 다음 중 파이썬 개발에 사용할 수 있는 IDE/에디터를 모두 고르시오.
① Visual Studio Code
② PyCharm
③ Photoshop
④ Sublime Text
⑤ IDLE
⑥ Excel
⑦ Jupyter Notebook
'''

## 1, 2, 4, 5, 7

# %%
# 1. / 연산자와 // 연산자의 차이점을 설명하시오.
## / 연산자는 나눈결과 // 연산자는 나눗셈 후 몫을 반환
print(7 / 4)
print(7 // 4)
# Out:
# 1.75
# 1

# %%
# 2. 다음 코드의 실행 결과를 쓰시오.
print(17 % 5)
print(23 % 7)
print(100 % 3)
# Out:
# 2
# 2
# 1

# %%
# 3. % 연산자는 무엇을 구하는 연산자인지 설명하고, 실생활에서 활용할 수 있는 예시를 하나 들어 쓰시오.
## % 연산자는 나눗셈 후에 나머지를 반환

week = ["월", "화", "수", "목", "금", "토", "일"]

today = input("오늘은 무슨 요일인가요? (월/화/수/목/금/토/일): ")
days = int(input("몇 일 후의 요일을 계산할까요?: "))

today_num = week.index(today)
result = (today_num + days) % 7

print(days, "일 후는", week[result], "요일입니다.")

## 실생활에서 %7을 통한 요일계산을 할 수 있다
# Out:
# 오늘은 무슨 요일인가요? (월/화/수/목/금/토/일): 화
# 몇 일 후의 요일을 계산할까요?: 10
# 10 일 후는 금 요일입니다.

# %%
# 4. ** 연산자가 의미하는 것을 설명하시오.
## 지수연산을 의미한다 8^2 == 8 ** 2
print(8**3)
print(8*8*8)
# Out:
# 512
# 512

# %%
'''
5. 다음 조건에 맞게 코드를 작성하시오.
- 변수 x에 8진수 25를 저장
- 변수 y에 16진수 FF를 저장
- x와 y의 합을 출력
'''
x = 0o25
y = 0xFF

print(x + y)
# Out:
# 276

# %%
'''
6. 원의 넓이를 계산하는 프로그램을 작성하시오.
- 반지름(r)은 변수로 저장 (예: r = 5)
- 원주율(pi)은 3.14159를 사용
- 공식: 넓이 = π × r²
'''
r = 5
pi = 3.14159
a = pi * (r**2)
print(a)
# Out:
# 78.53975

# %%
'''
7. 복리 이자를 계산하는 프로그램을 작성하시오.
- 원금(principal): 1,000,000원
- 연이율(rate): 5% (0.05)
- 기간(years): 3년
- 공식: 최종금액 = 원금 × (1 + 연이율)^기간
'''
p = 1000000
r = 0.05
y = 3
a = p * (1 + r)**3
print(a)
# Out:
# 1157625.0000000002

# %%
###문자 자료형

# %%
# 1. 파이썬에서 문자열을 만드는 4가지 방법을 쓰시오

## 1. 큰 따옴표
print("Hello World")

## 2. 작은 따옴표
print('python is fun')

## 3. 큰따옴표 3개를 연속으로 감싸기
print("""Life is too short, You need python""")

## 4. 작은따옴표 3개를 연속으로 감싸기
print('''Life is too short, You need python''')
# Out:
# Hello World
# python is fun
# Life is too short, You need python
# Life is too short, You need python

# %%
# 2. 다음 문자열을 출력하시오 - Python's favorite food is perl
print("Python\'s favorite food is perl")
# Out:
# Python's favorite food is perl

# %%
# 3. 다음 문자열을 출력하시오 - "Python is very eash" he says
print('"Python is very eash" he says')
# Out:
# "Python is very eash" he says

# %%
# 4. 다음 코드에서 에러가 발생하는 이유를 설명하고 올바르게 수정하시오  - msg = 'It's a beautiful day
## 작은따옴표가 It만 감싸고있어 이 부분만 문자열로 인식 전체를 끈따옴표로 감싸 해결한다
msg = "'It's a beautiful day"
print(msg)
# Out:
# 'It's a beautiful day

# %%
# 5. 다음 이스케이프 코드의 의미를 쓰시오. (5점)
## (1) \n : 줄바꿈
## (2) \t : 탭, 일정간격 띄우기
## (3) \\ : 이스케이프코드로 역슬래시 출력
## (4) \' : 이스케이프코드로 작은따옴표 출력
## (5) \" : 이스케이프코드로 큰따옴표 출력
print("Python\'s favorite \nfood is perl")
print("Python\'s favorite \tfood is perl")
print("Python\'s \\favorite food \\is \\perl")
print("Python\'s favorite book is \"Harry Potter\"")
# Out:
# Python's favorite
# food is perl
# Python's favorite 	food is perl
# Python's \favorite food \is \perl
# Python's favorite book is "Harry Potter"

# %%
# 6. 다음 코드의 실행 결과를 쓰시오. - print("C:\\Users\\python\\test.py")
print("C:\\Users\\python\\test.py")
# Out:
# C:\Users\python\test.py

# %%
# 7. len() 함수는 무엇을 반환하는지 설명하시오
## 문자열의 길이를 반환
a = "Life is too short"
len(a)
# Out:
# 17

# %%
# 8. 문자열 인덱싱에서 a[-1]이 의미하는 것을 설명하시오.
## 문자열의 맨 마지막
a = "Life is too short"
print(a[-1])
# Out:
# t

# %%
# 9. 다음 코드의 실행 결과를 쓰시오. (4점)
a = "Life is too short, You need Python"
print(a[12])
print(a[-5])
# Out:
# s
# y

# %%
# 10. 다음 코드의 실행 결과를 쓰시오.
a = "Life is too short, You need Python"
print(a[0:4])
# Out:
# Life

# %%
# 11. 문자열 "Hello World"에서 인덱싱을 이용하여 "WH"를 출력하는 코드를 작성하시오
a = "Hello World"
print(a[6]+a[0])
# Out:
# WH
